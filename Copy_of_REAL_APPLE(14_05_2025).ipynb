# %%
! pip install -q kaggle

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-84a1731a-dd10-4726-ba83-da9c3038b354" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84a1731a-dd10-4726-ba83-da9c3038b354">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d rijulbansal01/apple-leaf-diseases-detection
! unzip "apple-leaf-diseases-detection.zip"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rijulbansal01/apple-leaf-diseases-detection
# License(s): CC0-1.0
# ...
#  71% 127M/179M [00:00<00:00, 1.31GB/s]
# 100% 179M/179M [00:00<00:00, 1.15GB/s]
# Archive:  apple-leaf-diseases-detection.zip
#   inflating: Alternaria leaf spot/000413.jpg
#   inflating: Alternaria leaf spot/000414.jpg
#   inflating: Alternaria leaf spot/000415.jpg
#   inflating: Alternaria leaf spot/000416.jpg
#   inflating: Alternaria leaf spot/000417.jpg
#   inflating: Alternaria leaf spot/000418.jpg
#   inflating: Alternaria leaf spot/000420.jpg
#   inflating: Alternaria leaf spot/000421.jpg
#   inflating: Alternaria leaf spot/000422.jpg
#   inflating: Alternaria leaf spot/000423.jpg
#   inflating: Alternaria leaf spot/000424.jpg
#   inflating: Alternaria leaf spot/000425.jpg
#   inflating: Alternaria leaf spot/000426.jpg
#   inflating: Alternaria leaf spot/000427.jpg
#   inflating: Alternaria leaf spot/000429.jpg
#   inflating: Alternaria leaf spot/000430.jpg
# ...

# %%
import os
import shutil
import uuid
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, BatchNormalization, Dense, GlobalAveragePooling2D, Input

# Setup paths
base_dir = f"temp_dataset_{uuid.uuid4().hex}"
train_dir = os.path.join(base_dir, "train")
test_dir = os.path.join(base_dir, "test")
os.makedirs(train_dir)
os.makedirs(test_dir)

dataset_paths = [
    "/content/Alternaria leaf spot",
    "/content/Brown spot",
    "/content/Gray spot",
    "/content/Healthy leaf",
    "/content/Rust"
]

# Data preparation
def collect_and_split(dataset_paths, train_dir, test_dir, split_ratio=0.8):
    image_paths, labels = [], []
    for class_dir in dataset_paths:
        class_name = os.path.basename(class_dir)
        if not os.path.isdir(class_dir):
            continue
        for img_file in os.listdir(class_dir):
            if img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_paths.append(os.path.join(class_dir, img_file))
                labels.append(class_name)

    train_paths, test_paths, train_labels, test_labels = train_test_split(
        image_paths, labels, train_size=split_ratio, stratify=labels, random_state=42)

    def copy_files(paths, labels, target_base):
        for img_path, label in zip(paths, labels):
            dest_dir = os.path.join(target_base, label)
            os.makedirs(dest_dir, exist_ok=True)
            shutil.copy(img_path, os.path.join(dest_dir, os.path.basename(img_path)))

    copy_files(train_paths, train_labels, train_dir)
    copy_files(test_paths, test_labels, test_dir)

collect_and_split(dataset_paths, train_dir, test_dir)

# Image generators
img_size = 128
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    train_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode='categorical'
)
test_data = test_datagen.flow_from_directory(
    test_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode='categorical', shuffle=False
)

# Model architecture
model = tf.keras.models.Sequential([
    Input(shape=(img_size, img_size, 3)),

    Conv2D(32, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.2),

    Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.3),

    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.4),

    Conv2D(256, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.4),

    GlobalAveragePooling2D(),

    Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),
    Dense(train_data.num_classes, activation='softmax')
])

# Model summary
model.summary()

# Compile model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train model
history = model.fit(train_data, epochs=10, validation_data=test_data)

# Save model
model.save("leaf_disease_model.h5")
print("💾 Model saved as 'leaf_disease_model.h5'")

# Evaluate model
loss, acc = model.evaluate(test_data)
print(f"\n✅ Final Test Accuracy: {acc:.4f}")

# Predictions
y_pred_probs = model.predict(test_data)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_data.classes
class_labels = list(test_data.class_indices.keys())

# Classification report
print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_labels, yticklabels=class_labels, cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Accuracy & loss curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Found 1312 images belonging to 5 classes.
# Found 329 images belonging to 5 classes.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 32)     │             0 │
# ...

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 MB 19.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.3/323.3 kB 29.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 111.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 4.8 MB/s eta 0:00:00
# ...

# %%
# !pip install gradio numpy pillow tensorflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 MB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.3/323.3 kB 26.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 96.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 6.6 MB/s eta 0:00:00
# ...

# %%
import numpy as np
from PIL import Image
import tensorflow as tf

# Load model (adjust path if needed)
model = tf.keras.models.load_model("leaf_disease_model.h5")

# Define class labels
class_names = ["Apple Scab", "Black Rot", "Cedar Apple Rust", "Healthy"]  # Example

def predict(image):
    try:
        # Preprocess image
        image = image.resize((224, 224))  # Match your model input
        img_array = np.array(image) / 255.0
        img_array = np.expand_dims(img_array, axis=0)

        # Predict
        preds = model.predict(img_array)
        predicted_index = np.argmax(preds)
        confidence = float(np.max(preds))

        # Get class label
        diagnosis = class_names[predicted_index]

        # Recommend an action (example logic)
        if diagnosis == "Healthy":
            action = "No action needed."
        else:
            action = "Apply appropriate treatment and monitor plant health."

        return diagnosis, f"{confidence:.2%}", action

    except Exception as e:
        # Print the error for debugging in Colab
        print("ERROR in prediction:", str(e))
        return "Error", "Error", "Error"
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import gradio as gr

interface = gr.Interface(
    fn=predict,
    inputs=gr.Image(type="pil", label="Upload Leaf Image"),
    outputs=[
        gr.Textbox(label="Diagnosis"),
        gr.Textbox(label="Confidence Level"),
        gr.Textbox(label="Recommended Action"),
    ],
    title="🍎 Apple Leaf Disease Classifier",
    description="Upload an image of an apple leaf for disease diagnosis"
)

interface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://45a8b6534426819db5.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://45a8b6534426819db5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
#1. Customized CNN

import os
import shutil
import uuid
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import (classification_report, confusion_matrix, roc_auc_score,
                             precision_score, recall_score, f1_score, fbeta_score, matthews_corrcoef)

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Dropout, BatchNormalization,
                                     Dense, GlobalAveragePooling2D, Input)
from tensorflow.keras.optimizers import Adam

# Setup paths
base_dir = f"temp_dataset_{uuid.uuid4().hex}"
train_dir = os.path.join(base_dir, "train")
test_dir = os.path.join(base_dir, "test")
os.makedirs(train_dir)
os.makedirs(test_dir)

dataset_paths = [
    "/content/Alternaria leaf spot",
    "/content/Brown spot",
    "/content/Gray spot",
    "/content/Healthy leaf",
    "/content/Rust"
]

# Data preparation
def collect_and_split(dataset_paths, train_dir, test_dir, split_ratio=0.8):
    image_paths, labels = [], []
    for class_dir in dataset_paths:
        class_name = os.path.basename(class_dir)
        if not os.path.isdir(class_dir):
            continue
        for img_file in os.listdir(class_dir):
            if img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_paths.append(os.path.join(class_dir, img_file))
                labels.append(class_name)

    train_paths, test_paths, train_labels, test_labels = train_test_split(
        image_paths, labels, train_size=split_ratio, stratify=labels, random_state=42)

    def copy_files(paths, labels, target_base):
        for img_path, label in zip(paths, labels):
            dest_dir = os.path.join(target_base, label)
            os.makedirs(dest_dir, exist_ok=True)
            shutil.copy(img_path, os.path.join(dest_dir, os.path.basename(img_path)))

    copy_files(train_paths, train_labels, train_dir)
    copy_files(test_paths, test_labels, test_dir)
    return len(image_paths), len(train_paths), len(test_paths), set(labels)

total_samples, train_samples, test_samples, class_names = collect_and_split(dataset_paths, train_dir, test_dir)

# Image generators
img_size = 128
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    train_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode='categorical'
)
test_data = test_datagen.flow_from_directory(
    test_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode='categorical', shuffle=False
)

# Customized CNN Model
input_shape = (img_size, img_size, 3)
hidden_layer_sizes = [32, 64, 128, 256]
num_classes = train_data.num_classes
activation_hidden = 'relu'
activation_output = 'softmax'
optimizer = Adam(learning_rate=0.001)
loss_fn = 'categorical_crossentropy'
epochs = 10

model = tf.keras.models.Sequential([
    Input(shape=input_shape),
    Conv2D(32, (3, 3), activation=activation_hidden, padding='same'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.2),
    Conv2D(64, (3, 3), activation=activation_hidden, padding='same'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.3),
    Conv2D(128, (3, 3), activation=activation_hidden, padding='same'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.4),
    Conv2D(256, (3, 3), activation=activation_hidden, padding='same'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.4),
    GlobalAveragePooling2D(),
    Dense(256, activation=activation_hidden, kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),
    Dense(num_classes, activation=activation_output)
])

model.summary()

model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# Training with time measurement
start_time = time.time()
history = model.fit(train_data, epochs=epochs, validation_data=test_data)
end_time = time.time()
execution_time_ms = (end_time - start_time) * 1000

# Save model
model.save("leaf_disease_model.h5")
print("💾 Model saved as 'leaf_disease_model.h5'")

# Evaluate model
loss, acc = model.evaluate(test_data)
print(f"\n✅ Final Test Accuracy: {acc:.4f}")

# Predictions
y_pred_probs = model.predict(test_data)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_data.classes
class_labels = list(test_data.class_indices.keys())

# Classification report
report = classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)
print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_labels, yticklabels=class_labels, cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC-AUCs (for multiclass)
try:
    aucs = roc_auc_score(tf.keras.utils.to_categorical(y_true, num_classes), y_pred_probs, average=None)
except:
    aucs = "Not computable (requires at least one positive and one negative sample per class)"

# Additional Metrics
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')
f2 = fbeta_score(y_true, y_pred, beta=2, average='weighted')
fbeta = fbeta_score(y_true, y_pred, beta=0.5, average='weighted')
miss_rate = 1 - recall
sensitivity = recall  # same as recall
specificity = np.mean([cm[i,i] / (cm[:,i].sum() if cm[:,i].sum() > 0 else 1) for i in range(num_classes)])
ppv = precision  # Positive Predictive Value
npv = np.nan  # Not directly available in multiclass without further calculation
fpr = np.nan  # False Positive Rate, needs per-class calculation
fnr = np.nan  # False Negative Rate, needs per-class calculation
lpr = np.nan  # Likelihood Positive Ratio
lnr = np.nan  # Likelihood Negative Ratio
fm_index = np.sqrt(precision * recall)
mcc = matthews_corrcoef(y_true, y_pred)

# Training/Validation accuracy and loss
train_acc = history.history['accuracy'][-1]
val_acc = history.history['val_accuracy'][-1]
train_loss = history.history['loss'][-1]
val_loss = history.history['val_loss'][-1]



import numpy as np

# ... (rest of your code above remains unchanged)

# Calculate per-class metrics for multiclass
def multiclass_metrics(cm):
    # cm: confusion matrix (num_classes x num_classes)
    num_classes = cm.shape[0]
    metrics = {
        'NPV': [],
        'FPR': [],
        'FNR': [],
        'LPR': [],
        'LNR': [],
        'Specificity': []
    }
    for i in range(num_classes):
        TP = cm[i, i]
        FP = cm[:, i].sum() - TP
        FN = cm[i, :].sum() - TP
        TN = cm.sum() - (TP + FP + FN)
        # Avoid division by zero
        NPV = TN / (TN + FN) if (TN + FN) > 0 else np.nan
        FPR = FP / (FP + TN) if (FP + TN) > 0 else np.nan
        FNR = FN / (FN + TP) if (FN + TP) > 0 else np.nan
        Specificity = TN / (TN + FP) if (TN + FP) > 0 else np.nan
        Sensitivity = TP / (TP + FN) if (TP + FN) > 0 else np.nan
        LPR = Sensitivity / FPR if FPR and FPR > 0 else np.nan
        LNR = FNR / Specificity if Specificity and Specificity > 0 else np.nan
        metrics['NPV'].append(NPV)
        metrics['FPR'].append(FPR)
        metrics['FNR'].append(FNR)
        metrics['LPR'].append(LPR)
        metrics['LNR'].append(LNR)
        metrics['Specificity'].append(Specificity)
    # Average across classes
    avg_metrics = {k: np.nanmean(v) for k, v in metrics.items()}
    return avg_metrics

# Compute confusion matrix metrics
cm_metrics = multiclass_metrics(cm)

# Now print all required parameters with actual values
print("\n--- Model & Dataset Parameters ---")
print(f"1. Sample Size: {total_samples}")
print(f"2. Train Dataset: {train_samples} | Test Dataset: {test_samples}")
print(f"3. Proposed Model: Customized CNN (see summary above)")
print(f"4. Sample Size: {total_samples}")
print(f"5. Input Size: {input_shape}")
print(f"6. Hidden Layer Size: {[256]} (Dense layer)")
print(f"7. Number of Neurons in Hidden Layer: 256")
print(f"8. Activation Function of Hidden Layer: {activation_hidden}")
print(f"9. Number of Neurons in Output Layer: {num_classes}")
print(f"10. Activation Function of Output Layer: {activation_output}")
print(f"11. Optimizer: Adam")
print(f"12. Loss Function: {loss_fn}")
print(f"13. Performance Metrics: Accuracy, Precision, Recall, F1, AUC, etc.")
print(f"14. Number of Epochs: {epochs}")
print(f"15. Learning Rate: {optimizer.learning_rate.numpy()}")
print(f"16. Execution Time (ms): {execution_time_ms:.2f}")
print(f"17. AUCs: {aucs}")
print(f"18. Training Accuracy: {train_acc:.4f}")
print(f"19. Testing Accuracy: {acc:.4f}")
print(f"20. Validation Accuracy: {val_acc:.4f}")
print(f"21. Training Loss: {train_loss:.4f}")
print(f"22. Validation Loss: {val_loss:.4f}")
print(f"23. Precision: {precision:.4f}")
print(f"24. Recall: {recall:.4f}")
print(f"25. Classification Miss Rate: {miss_rate:.4f}")
print(f"26. Sensitivity: {sensitivity:.4f}")
print(f"27. Specificity: {cm_metrics['Specificity']:.4f}")
print(f"28. F1-Score: {f1:.4f}")
print(f"29. F2-Score: {f2:.4f}")
print(f"30. FBeta-Score (beta=0.5): {fbeta:.4f}")
print(f"31. Positive Predicted Value (PPV): {ppv:.4f}")
print(f"32. Negative Predicted Value (NPV): {cm_metrics['NPV']:.4f}")
print(f"33. False Positive Ratio (FPR): {cm_metrics['FPR']:.4f}")
print(f"34. False Negative Ratio (FNR): {cm_metrics['FNR']:.4f}")
print(f"35. Likelihood Positive Ratio (LPR): {cm_metrics['LPR']:.4f}")
print(f"36. Likelihood Negative Ratio (LNR): {cm_metrics['LNR']:.4f}")
print(f"37. Fowlkes-Mallows index: {fm_index:.4f}")
print(f"38. Matthews Correlation Coefficient: {mcc:.4f}")



# Accuracy & loss curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Found 1312 images belonging to 5 classes.
# Found 329 images belonging to 5 classes.
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_28 (Conv2D)              │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_28          │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_28 (MaxPooling2D) │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_35 (Dropout)            │ (None, 64, 64, 32)     │             0 │
# ...

# %%
#1. VGG19-based CNN

import os
import shutil
import uuid
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, confusion_matrix, roc_auc_score, precision_score,
    recall_score, f1_score, fbeta_score, accuracy_score, roc_curve
)
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG19
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam

# Setup paths
base_dir = f"temp_dataset_{uuid.uuid4().hex}"
train_dir = os.path.join(base_dir, "train")
test_dir = os.path.join(base_dir, "test")
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

dataset_paths = [
    "/content/Alternaria leaf spot",
    "/content/Brown spot",
    "/content/Gray spot",
    "/content/Healthy leaf",
    "/content/Rust"
]

# Data preparation
def collect_and_split(dataset_paths, train_dir, test_dir, split_ratio=0.8):
    image_paths, labels = [], []
    for class_dir in dataset_paths:
        class_name = os.path.basename(class_dir)
        if not os.path.isdir(class_dir):
            continue
        for img_file in os.listdir(class_dir):
            if img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_paths.append(os.path.join(class_dir, img_file))
                labels.append(class_name)

    train_paths, test_paths, train_labels, test_labels = train_test_split(
        image_paths, labels, train_size=split_ratio, stratify=labels, random_state=42
    )

    def copy_files(paths, labels, target_base):
        for img_path, label in zip(paths, labels):
            dest_dir = os.path.join(target_base, label)
            os.makedirs(dest_dir, exist_ok=True)
            shutil.copy(img_path, os.path.join(dest_dir, os.path.basename(img_path)))

    copy_files(train_paths, train_labels, train_dir)
    copy_files(test_paths, test_labels, test_dir)
    return train_paths, test_paths, train_labels, test_labels

train_paths, test_paths, train_labels, test_labels = collect_and_split(dataset_paths, train_dir, test_dir)

# Image generators
img_size = 128
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    train_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode='categorical'
)
test_data = test_datagen.flow_from_directory(
    test_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode='categorical', shuffle=False
)

# Model architecture: VGG19
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))
base_model.trainable = False  # Freeze base

model = tf.keras.models.Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),
    Dense(train_data.num_classes, activation='softmax')
])

# Model summary
model.summary()

# Compile model
learning_rate = 0.0001
optimizer = Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train model
epochs = 10
start_time = time.time()
history = model.fit(train_data, epochs=epochs, validation_data=test_data)
end_time = time.time()
execution_time_ms = (end_time - start_time) * 1000

# Save model
model.save("leaf_disease_model_vgg19.h5")
print("💾 Model saved as 'leaf_disease_model_vgg19.h5'")

# Evaluate model
loss, acc = model.evaluate(test_data)
print(f"\n✅ Final Test Accuracy: {acc:.4f}")

# Predictions
y_pred_probs = model.predict(test_data)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_data.classes
class_labels = list(test_data.class_indices.keys())

# Classification report
report = classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)
print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_labels, yticklabels=class_labels, cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Accuracy & loss curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# --- Metrics Calculation ---
# AUCs (for each class, macro, and weighted)
try:
    aucs = roc_auc_score(test_data.labels, y_pred_probs, multi_class='ovr', average=None)
    auc_macro = roc_auc_score(test_data.labels, y_pred_probs, multi_class='ovr', average='macro')
    auc_weighted = roc_auc_score(test_data.labels, y_pred_probs, multi_class='ovr', average='weighted')
except:
    aucs = auc_macro = auc_weighted = "N/A (not enough samples per class)"

# Precision, Recall, F1, F2, FBeta, etc.
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')
f2 = fbeta_score(y_true, y_pred, beta=2, average='macro')
fbeta = fbeta_score(y_true, y_pred, beta=0.5, average='macro')

# Miss Rate, Sensitivity, Specificity, PPV, NPV, FPR, FNR, LPR, LNR, FM index
TP = np.diag(cm)
FP = cm.sum(axis=0) - TP
FN = cm.sum(axis=1) - TP
TN = cm.sum() - (FP + FN + TP)

sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
miss_rate = FN / (FN + TP)
ppv = TP / (TP + FP)
npv = TN / (TN + FN)
fpr = FP / (FP + TN)
fnr = FN / (FN + TP)
lpr = sensitivity / (1 - specificity)
lnr = (1 - sensitivity) / specificity
fm_index = np.sqrt(precision * recall)

# Print all requested parameters
print("\n--- Model & Dataset Parameters ---")
print(f"1. Sample Size: {len(train_paths) + len(test_paths)}")
print(f"2. Train Dataset: {len(train_paths)} | Test Dataset: {len(test_paths)}")
print(f"3. Proposed Model: VGG19-based CNN")
print(f"4. Sample Size: {len(train_paths) + len(test_paths)}")
print(f"5. Input Size: {img_size}x{img_size}x3")
print(f"6. Hidden Layer Size: 256")
print(f"7. Number of Neurons in Hidden Layer: 256")
print(f"8. Activation Function of Hidden Layer: relu")
print(f"9. No of Neurons in Output Layer: {train_data.num_classes}")
print(f"10. Activation Function of Output Layer: softmax")
print(f"11. Optimizer: Adam")
print(f"12. Loss Function: categorical_crossentropy")
print(f"13. Performance Metrics: accuracy, precision, recall, F1, AUC")
print(f"14. No of Epochs: {epochs}")
print(f"15. Learning Rate: {learning_rate}")
print(f"16. Execution time (in ms): {execution_time_ms:.2f}")
print(f"17. AUCs (per class): {aucs}")
print(f"    Macro AUC: {auc_macro}")
print(f"    Weighted AUC: {auc_weighted}")
print(f"18. Training Accuracy: {history.history['accuracy'][-1]:.4f}")
print(f"19. Testing Accuracy: {acc:.4f}")
print(f"20. Validation Accuracy: {history.history['val_accuracy'][-1]:.4f}")
print(f"21. Loss: {loss:.4f}")
print(f"22. Validation Loss: {history.history['val_loss'][-1]:.4f}")
print(f"23. Precision (macro): {precision:.4f}")
print(f"24. Recall (macro): {recall:.4f}")
print(f"25. Classification Miss Rate (macro): {miss_rate.mean():.4f}")
print(f"26. Sensitivity (macro): {sensitivity.mean():.4f}")
print(f"27. Specificity (macro): {specificity.mean():.4f}")
print(f"28. F1-Score (macro): {f1:.4f}")
print(f"29. F2-Score (macro): {f2:.4f}")
print(f"30. FBeta-Score (beta=0.5, macro): {fbeta:.4f}")
print(f"31. Positive Predicted Value (macro): {ppv.mean():.4f}")
print(f"32. Negative Predicted Value (macro): {npv.mean():.4f}")
print(f"33. False Positive Ratio (macro): {fpr.mean():.4f}")
print(f"34. False Negative Ratio (macro): {fnr.mean():.4f}")
print(f"35. Likelihood Positive Ratio (macro): {lpr.mean():.4f}")
print(f"36. Likelihood Negative Ratio (macro): {lnr.mean():.4f}")
print(f"37. Fowlkes-Mallows index (macro): {fm_index.mean():.4f}")
# Out:
# Found 1312 images belonging to 5 classes.
# Found 329 images belonging to 5 classes.
# ...
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg19 (Functional)              │ (None, 4, 4, 512)      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
#2. RsetNet50

import os
import shutil
import uuid
import time
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import (classification_report, confusion_matrix, roc_auc_score, precision_score,
                             recall_score, f1_score, fbeta_score, matthews_corrcoef)

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam

# Setup paths
base_dir = f"temp_dataset_{uuid.uuid4().hex}"
train_dir = os.path.join(base_dir, "train")
test_dir = os.path.join(base_dir, "test")
os.makedirs(train_dir)
os.makedirs(test_dir)

dataset_paths = [
    "/content/Alternaria leaf spot",
    "/content/Brown spot",
    "/content/Gray spot",
    "/content/Healthy leaf",
    "/content/Rust"
]

# Data preparation
def collect_and_split(dataset_paths, train_dir, test_dir, split_ratio=0.8):
    image_paths, labels = [], []
    for class_dir in dataset_paths:
        class_name = os.path.basename(class_dir)
        if not os.path.isdir(class_dir): continue
        for img_file in os.listdir(class_dir):
            if img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_paths.append(os.path.join(class_dir, img_file))
                labels.append(class_name)

    train_paths, test_paths, train_labels, test_labels = train_test_split(
        image_paths, labels, train_size=split_ratio, stratify=labels, random_state=42)

    def copy_files(paths, labels, target_base):
        for img_path, label in zip(paths, labels):
            dest_dir = os.path.join(target_base, label)
            os.makedirs(dest_dir, exist_ok=True)
            shutil.copy(img_path, os.path.join(dest_dir, os.path.basename(img_path)))

    copy_files(train_paths, train_labels, train_dir)
    copy_files(test_paths, test_labels, test_dir)
    return len(image_paths), len(train_paths), len(test_paths)

total_samples, train_samples, test_samples = collect_and_split(dataset_paths, train_dir, test_dir)

# Image generators
img_size = 224
batch_size = 32

train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=25, width_shift_range=0.2,
                                   height_shift_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(train_dir, target_size=(img_size, img_size),
                                               batch_size=batch_size, class_mode='categorical')
test_data = test_datagen.flow_from_directory(test_dir, target_size=(img_size, img_size),
                                             batch_size=batch_size, class_mode='categorical', shuffle=False)

# Load ResNet50 base
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))
for layer in base_model.layers:
    layer.trainable = False

# Add custom top layers
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(train_data.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

model.summary()

# Train model
start_time = time.time()
history = model.fit(train_data, epochs=10, validation_data=test_data)
end_time = time.time()

# Evaluate
loss, test_accuracy, test_auc = model.evaluate(test_data)

# Predictions
y_probs = model.predict(test_data)
y_pred = np.argmax(y_probs, axis=1)
y_true = test_data.classes
class_labels = list(test_data.class_indices.keys())

# Classification Metrics
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')
f2 = fbeta_score(y_true, y_pred, beta=2, average='weighted')
f_beta = fbeta_score(y_true, y_pred, beta=1.5, average='weighted')
miss_rate = 1 - test_accuracy
sensitivity = recall
conf_matrix = confusion_matrix(y_true, y_pred)
tn = np.sum(conf_matrix) - (np.sum(conf_matrix, axis=1) + np.sum(conf_matrix, axis=0) - np.diag(conf_matrix))
fp = np.sum(conf_matrix) - np.trace(conf_matrix) - np.sum(conf_matrix, axis=0) + np.diag(conf_matrix)
fn = np.sum(conf_matrix) - np.trace(conf_matrix) - np.sum(conf_matrix, axis=1) + np.diag(conf_matrix)
tp = np.diag(conf_matrix)

specificity = np.mean(tp / (tp + fp + 1e-7))
ppv = precision
npv = np.mean(tn / (tn + fn + 1e-7))
fpr = np.mean(fp / (fp + tn + 1e-7))
fnr = np.mean(fn / (fn + tp + 1e-7))
lr_pos = sensitivity / (1 - specificity + 1e-7)
lr_neg = (1 - sensitivity) / (specificity + 1e-7)
fm_index = np.sqrt(precision * recall)

# Print all metrics
print("\n📊 Performance Summary:")
print(f"1. Sample Size: {total_samples}")
print(f"2. Train Dataset: {train_samples} | Test Dataset: {test_samples}")
print("3. Proposed Model: ResNet50 (Transfer Learning)")
print(f"5. Input Size: {img_size}x{img_size}x3")
print("6. Hidden Layer Size: 1 (Dense: 256)")
print("7. Number of Neurons in Hidden Layer: 256")
print("8. Activation Function of Hidden Layer: ReLU")
print(f"9. No of Neurons in Output Layer: {len(class_labels)}")
print("10. Activation Function of Output Layer: Softmax")
print("11. Optimizer: Adam")
print("12. Loss Function: Categorical Crossentropy")
print("13. Performance Metrics: Accuracy, Precision, Recall, AUC, F1, etc.")
print("14. No of Epochs: 10")
print("15. Learning Rate: 0.0001")
print(f"16. Execution Time: {round((end_time - start_time) * 1000, 2)} ms")
print(f"17. AUC: {test_auc:.4f}")
print(f"18. Training Accuracy: {history.history['accuracy'][-1]:.4f}")
print(f"19. Testing Accuracy: {test_accuracy:.4f}")
print(f"20. Validation Accuracy: {history.history['val_accuracy'][-1]:.4f}")
print(f"21. Loss: {loss:.4f}")
print(f"22. Validation Loss: {history.history['val_loss'][-1]:.4f}")
print(f"23. Precision: {precision:.4f}")
print(f"24. Recall: {recall:.4f}")
print(f"25. Classification Miss Rate: {miss_rate:.4f}")
print(f"26. Sensitivity: {sensitivity:.4f}")
print(f"27. Specificity: {specificity:.4f}")
print(f"28. F1-Score: {f1:.4f}")
print(f"29. F2-Score: {f2:.4f}")
print(f"30. Fβ-Score (β=1.5): {f_beta:.4f}")
print(f"31. Positive Predicted Value (PPV): {ppv:.4f}")
print(f"32. Negative Predicted Value (NPV): {npv:.4f}")
print(f"33. False Positive Ratio (FPR): {fpr:.4f}")
print(f"34. False Negative Ratio (FNR): {fnr:.4f}")
print(f"35. Likelihood Positive Ratio: {lr_pos:.4f}")
print(f"36. Likelihood Negative Ratio: {lr_neg:.4f}")
print(f"37. Fowlkes-Mallows Index: {fm_index:.4f}")

# Plot accuracy and loss curves
plt.figure(figsize=(12, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='o')
plt.title("Accuracy Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')
plt.title("Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# Confusion Matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Bar plot for key performance metrics
metric_names = [
    "Precision", "Recall", "F1-Score", "F2-Score", "AUC",
    "Specificity", "NPV", "FPR", "FNR", "FM Index"
]
metric_values = [
    precision, recall, f1, f2, test_auc,
    specificity, npv, fpr, fnr, fm_index
]

plt.figure(figsize=(12, 6))
sns.barplot(x=metric_names, y=metric_values, palette="viridis")
plt.ylim(0, 1)
plt.ylabel("Score")
plt.title("Model Evaluation Metrics")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# Found 1312 images belonging to 5 classes.
# Found 329 images belonging to 5 classes.
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ input_layer_5[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ...

# %%
#3. Inception-V3

import os
import shutil
import uuid
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, confusion_matrix, roc_auc_score, precision_score,
    recall_score, f1_score, fbeta_score
)
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam

# Setup paths
base_dir = f"temp_dataset_{uuid.uuid4().hex}"
train_dir = os.path.join(base_dir, "train")
test_dir = os.path.join(base_dir, "test")
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

dataset_paths = [
    "/content/Alternaria leaf spot",
    "/content/Brown spot",
    "/content/Gray spot",
    "/content/Healthy leaf",
    "/content/Rust"
]

# Data preparation
def collect_and_split(dataset_paths, train_dir, test_dir, split_ratio=0.8):
    image_paths, labels = [], []
    for class_dir in dataset_paths:
        class_name = os.path.basename(class_dir)
        if not os.path.isdir(class_dir):
            continue
        for img_file in os.listdir(class_dir):
            if img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_paths.append(os.path.join(class_dir, img_file))
                labels.append(class_name)

    train_paths, test_paths, train_labels, test_labels = train_test_split(
        image_paths, labels, train_size=split_ratio, stratify=labels, random_state=42)

    def copy_files(paths, labels, target_base):
        for img_path, label in zip(paths, labels):
            dest_dir = os.path.join(target_base, label)
            os.makedirs(dest_dir, exist_ok=True)
            shutil.copy(img_path, os.path.join(dest_dir, os.path.basename(img_path)))

    copy_files(train_paths, train_labels, train_dir)
    copy_files(test_paths, test_labels, test_dir)
    return train_paths, test_paths, train_labels, test_labels

train_paths, test_paths, train_labels, test_labels = collect_and_split(dataset_paths, train_dir, test_dir)

# Image generators
img_size = 128
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    train_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode='categorical'
)
test_data = test_datagen.flow_from_directory(
    test_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode='categorical', shuffle=False
)

# Model architecture: InceptionV3
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))
base_model.trainable = False  # Freeze base

model = tf.keras.models.Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(train_data.num_classes, activation='softmax')
])

model.summary()

# Compile model
learning_rate = 0.0001
optimizer = Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train model
epochs = 10
start_time = time.time()
history = model.fit(train_data, epochs=epochs, validation_data=test_data)
end_time = time.time()
execution_time_ms = (end_time - start_time) * 1000

# Save model
model.save("leaf_disease_model_inceptionv3.h5")
print("💾 Model saved as 'leaf_disease_model_inceptionv3.h5'")

# Evaluate model
loss, acc = model.evaluate(test_data)
print(f"\n✅ Final Test Accuracy: {acc:.4f}")

# Predictions
y_pred_probs = model.predict(test_data)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_data.classes
class_labels = list(test_data.class_indices.keys())

# Classification report
report = classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)
print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_labels, yticklabels=class_labels, cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Accuracy & loss curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# --- Metrics Calculation ---
try:
    aucs = roc_auc_score(test_data.labels, y_pred_probs, multi_class='ovr', average=None)
    auc_macro = roc_auc_score(test_data.labels, y_pred_probs, multi_class='ovr', average='macro')
    auc_weighted = roc_auc_score(test_data.labels, y_pred_probs, multi_class='ovr', average='weighted')
except Exception as e:
    aucs = auc_macro = auc_weighted = "N/A (not enough samples per class)"

precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)
f2 = fbeta_score(y_true, y_pred, beta=2, average='macro', zero_division=0)
fbeta = fbeta_score(y_true, y_pred, beta=0.5, average='macro', zero_division=0)

TP = np.diag(cm)
FP = cm.sum(axis=0) - TP
FN = cm.sum(axis=1) - TP
TN = cm.sum() - (FP + FN + TP)

sensitivity = TP / (TP + FN + 1e-8)
specificity = TN / (TN + FP + 1e-8)
miss_rate = FN / (FN + TP + 1e-8)
ppv = TP / (TP + FP + 1e-8)
npv = TN / (TN + FN + 1e-8)
fpr = FP / (FP + TN + 1e-8)
fnr = FN / (FN + TP + 1e-8)
lpr = sensitivity / (1 - specificity + 1e-8)
lnr = (1 - sensitivity) / (specificity + 1e-8)
fm_index = np.sqrt(precision * recall)

print("\n--- Model & Dataset Parameters ---")
print(f"1. Sample Size: {len(train_paths) + len(test_paths)}")
print(f"2. Train Dataset: {len(train_paths)} | Test Dataset: {len(test_paths)}")
print(f"3. Proposed Model: InceptionV3-based CNN")
print(f"4. Sample Size: {len(train_paths) + len(test_paths)}")
print(f"5. Input Size: {img_size}x{img_size}x3")
print(f"6. Hidden Layer Size: 256")
print(f"7. Number of Neurons in Hidden Layer: 256")
print(f"8. Activation Function of Hidden Layer: relu")
print(f"9. No of Neurons in Output Layer: {train_data.num_classes}")
print(f"10. Activation Function of Output Layer: softmax")
print(f"11. Optimizer: Adam")
print(f"12. Loss Function: categorical_crossentropy")
print(f"13. Performance Metrics: accuracy, precision, recall, F1, AUC")
print(f"14. No of Epochs: {epochs}")
print(f"15. Learning Rate: {learning_rate}")
print(f"16. Execution time (in ms): {execution_time_ms:.2f}")
print(f"17. AUCs (per class): {aucs}")
print(f"    Macro AUC: {auc_macro}")
print(f"    Weighted AUC: {auc_weighted}")
print(f"18. Training Accuracy: {history.history['accuracy'][-1]:.4f}")
print(f"19. Testing Accuracy: {acc:.4f}")
print(f"20. Validation Accuracy: {history.history['val_accuracy'][-1]:.4f}")
print(f"21. Loss: {loss:.4f}")
print(f"22. Validation Loss: {history.history['val_loss'][-1]:.4f}")
print(f"23. Precision (macro): {precision:.4f}")
print(f"24. Recall (macro): {recall:.4f}")
print(f"25. Classification Miss Rate (macro): {miss_rate.mean():.4f}")
print(f"26. Sensitivity (macro): {sensitivity.mean():.4f}")
print(f"27. Specificity (macro): {specificity.mean():.4f}")
print(f"28. F1-Score (macro): {f1:.4f}")
print(f"29. F2-Score (macro): {f2:.4f}")
print(f"30. FBeta-Score (beta=0.5, macro): {fbeta:.4f}")
print(f"31. Positive Predicted Value (macro): {ppv.mean():.4f}")
print(f"32. Negative Predicted Value (macro): {npv.mean():.4f}")
print(f"33. False Positive Ratio (macro): {fpr.mean():.4f}")
print(f"34. False Negative Ratio (macro): {fnr.mean():.4f}")
print(f"35. Likelihood Positive Ratio (macro): {lpr.mean():.4f}")
print(f"36. Likelihood Negative Ratio (macro): {lnr.mean():.4f}")
print(f"37. Fowlkes-Mallows index (macro): {fm_index:.4f}")
# Out:
# Found 1312 images belonging to 5 classes.
# Found 329 images belonging to 5 classes.
# ...
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)       │ (None, 2, 2, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_5      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
#4. MoblieNet-V2

import os
import shutil
import uuid
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, confusion_matrix, roc_auc_score, precision_score,
    recall_score, f1_score, fbeta_score
)
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam

# Setup paths
base_dir = f"temp_dataset_{uuid.uuid4().hex}"
train_dir = os.path.join(base_dir, "train")
test_dir = os.path.join(base_dir, "test")
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

dataset_paths = [
    "/content/Alternaria leaf spot",
    "/content/Brown spot",
    "/content/Gray spot",
    "/content/Healthy leaf",
    "/content/Rust"
]

# Data preparation
def collect_and_split(dataset_paths, train_dir, test_dir, split_ratio=0.8):
    image_paths, labels = [], []
    for class_dir in dataset_paths:
        class_name = os.path.basename(class_dir)
        if not os.path.isdir(class_dir):
            continue
        for img_file in os.listdir(class_dir):
            if img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_paths.append(os.path.join(class_dir, img_file))
                labels.append(class_name)

    train_paths, test_paths, train_labels, test_labels = train_test_split(
        image_paths, labels, train_size=split_ratio, stratify=labels, random_state=42)

    def copy_files(paths, labels, target_base):
        for img_path, label in zip(paths, labels):
            dest_dir = os.path.join(target_base, label)
            os.makedirs(dest_dir, exist_ok=True)
            shutil.copy(img_path, os.path.join(dest_dir, os.path.basename(img_path)))

    copy_files(train_paths, train_labels, train_dir)
    copy_files(test_paths, test_labels, test_dir)
    return train_paths, test_paths, train_labels, test_labels

train_paths, test_paths, train_labels, test_labels = collect_and_split(dataset_paths, train_dir, test_dir)

# Image generators
img_size = 128
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    train_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode='categorical'
)
test_data = test_datagen.flow_from_directory(
    test_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode='categorical', shuffle=False
)

# Model architecture: MobileNetV2
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))
base_model.trainable = False  # Freeze base

model = tf.keras.models.Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(train_data.num_classes, activation='softmax')
])

model.summary()

# Compile model
learning_rate = 0.0001
optimizer = Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train model
epochs = 10
start_time = time.time()
history = model.fit(train_data, epochs=epochs, validation_data=test_data)
end_time = time.time()
execution_time_ms = (end_time - start_time) * 1000

# Save model
model.save("leaf_disease_model_mobilenetv2.h5")
print("💾 Model saved as 'leaf_disease_model_mobilenetv2.h5'")

# Evaluate model
loss, acc = model.evaluate(test_data)
print(f"\n✅ Final Test Accuracy: {acc:.4f}")

# Predictions
y_pred_probs = model.predict(test_data)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_data.classes
class_labels = list(test_data.class_indices.keys())

# Classification report
report = classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)
print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_labels, yticklabels=class_labels, cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Accuracy & loss curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# --- Metrics Calculation ---
try:
    aucs = roc_auc_score(test_data.labels, y_pred_probs, multi_class='ovr', average=None)
    auc_macro = roc_auc_score(test_data.labels, y_pred_probs, multi_class='ovr', average='macro')
    auc_weighted = roc_auc_score(test_data.labels, y_pred_probs, multi_class='ovr', average='weighted')
except Exception as e:
    aucs = auc_macro = auc_weighted = "N/A (not enough samples per class)"

precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)
f2 = fbeta_score(y_true, y_pred, beta=2, average='macro', zero_division=0)
fbeta = fbeta_score(y_true, y_pred, beta=0.5, average='macro', zero_division=0)

TP = np.diag(cm)
FP = cm.sum(axis=0) - TP
FN = cm.sum(axis=1) - TP
TN = cm.sum() - (FP + FN + TP)

sensitivity = TP / (TP + FN + 1e-8)
specificity = TN / (TN + FP + 1e-8)
miss_rate = FN / (FN + TP + 1e-8)
ppv = TP / (TP + FP + 1e-8)
npv = TN / (TN + FN + 1e-8)
fpr = FP / (FP + TN + 1e-8)
fnr = FN / (FN + TP + 1e-8)
lpr = sensitivity / (1 - specificity + 1e-8)
lnr = (1 - sensitivity) / (specificity + 1e-8)
fm_index = np.sqrt(precision * recall)

print("\n--- Model & Dataset Parameters ---")
print(f"1. Sample Size: {len(train_paths) + len(test_paths)}")
print(f"2. Train Dataset: {len(train_paths)} | Test Dataset: {len(test_paths)}")
print(f"3. Proposed Model: MobileNetV2-based CNN")
print(f"4. Sample Size: {len(train_paths) + len(test_paths)}")
print(f"5. Input Size: {img_size}x{img_size}x3")
print(f"6. Hidden Layer Size: 256")
print(f"7. Number of Neurons in Hidden Layer: 256")
print(f"8. Activation Function of Hidden Layer: relu")
print(f"9. No of Neurons in Output Layer: {train_data.num_classes}")
print(f"10. Activation Function of Output Layer: softmax")
print(f"11. Optimizer: Adam")
print(f"12. Loss Function: categorical_crossentropy")
print(f"13. Performance Metrics: accuracy, precision, recall, F1, AUC")
print(f"14. No of Epochs: {epochs}")
print(f"15. Learning Rate: {learning_rate}")
print(f"16. Execution time (in ms): {execution_time_ms:.2f}")
print(f"17. AUCs (per class): {aucs}")
print(f"    Macro AUC: {auc_macro}")
print(f"    Weighted AUC: {auc_weighted}")
print(f"18. Training Accuracy: {history.history['accuracy'][-1]:.4f}")
print(f"19. Testing Accuracy: {acc:.4f}")
print(f"20. Validation Accuracy: {history.history['val_accuracy'][-1]:.4f}")
print(f"21. Loss: {loss:.4f}")
print(f"22. Validation Loss: {history.history['val_loss'][-1]:.4f}")
print(f"23. Precision (macro): {precision:.4f}")
print(f"24. Recall (macro): {recall:.4f}")
print(f"25. Classification Miss Rate (macro): {miss_rate.mean():.4f}")
print(f"26. Sensitivity (macro): {sensitivity.mean():.4f}")
print(f"27. Specificity (macro): {specificity.mean():.4f}")
print(f"28. F1-Score (macro): {f1:.4f}")
print(f"29. F2-Score (macro): {f2:.4f}")
print(f"30. FBeta-Score (beta=0.5, macro): {fbeta:.4f}")
print(f"31. Positive Predicted Value (macro): {ppv.mean():.4f}")
print(f"32. Negative Predicted Value (macro): {npv.mean():.4f}")
print(f"33. False Positive Ratio (macro): {fpr.mean():.4f}")
print(f"34. False Negative Ratio (macro): {fnr.mean():.4f}")
print(f"35. Likelihood Positive Ratio (macro): {lpr.mean():.4f}")
print(f"36. Likelihood Negative Ratio (macro): {lnr.mean():.4f}")
print(f"37. Fowlkes-Mallows index (macro): {fm_index:.4f}")
# Out:
# Found 1312 images belonging to 5 classes.
# Found 329 images belonging to 5 classes.
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_128            │ (None, 4, 4, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_7      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 256)            │       327,936 │
# ...

# %%
#5.  EfficientNetB0

import os
import shutil
import uuid
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, confusion_matrix, roc_auc_score, precision_score,
    recall_score, f1_score, fbeta_score
)
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam

# Setup paths
base_dir = f"temp_dataset_{uuid.uuid4().hex}"
train_dir = os.path.join(base_dir, "train")
test_dir = os.path.join(base_dir, "test")
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

dataset_paths = [
    "/content/Alternaria leaf spot",
    "/content/Brown spot",
    "/content/Gray spot",
    "/content/Healthy leaf",
    "/content/Rust"
]

# Data preparation
def collect_and_split(dataset_paths, train_dir, test_dir, split_ratio=0.8):
    image_paths, labels = [], []
    for class_dir in dataset_paths:
        class_name = os.path.basename(class_dir)
        if not os.path.isdir(class_dir):
            continue
        for img_file in os.listdir(class_dir):
            if img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_paths.append(os.path.join(class_dir, img_file))
                labels.append(class_name)

    train_paths, test_paths, train_labels, test_labels = train_test_split(
        image_paths, labels, train_size=split_ratio, stratify=labels, random_state=42)

    def copy_files(paths, labels, target_base):
        for img_path, label in zip(paths, labels):
            dest_dir = os.path.join(target_base, label)
            os.makedirs(dest_dir, exist_ok=True)
            shutil.copy(img_path, os.path.join(dest_dir, os.path.basename(img_path)))

    copy_files(train_paths, train_labels, train_dir)
    copy_files(test_paths, test_labels, test_dir)
    return train_paths, test_paths, train_labels, test_labels

train_paths, test_paths, train_labels, test_labels = collect_and_split(dataset_paths, train_dir, test_dir)

# Image generators
img_size = 128
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    train_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode='categorical'
)
test_data = test_datagen.flow_from_directory(
    test_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode='categorical', shuffle=False
)

# Model architecture: EfficientNetB0
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))
base_model.trainable = False  # Freeze base

model = tf.keras.models.Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(train_data.num_classes, activation='softmax')
])

model.summary()

# Compile model
learning_rate = 0.0001
optimizer = Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train model
epochs = 10
start_time = time.time()
history = model.fit(train_data, epochs=epochs, validation_data=test_data)
end_time = time.time()
execution_time_ms = (end_time - start_time) * 1000

# Save model
model.save("leaf_disease_model_efficientnetb0.h5")
print("💾 Model saved as 'leaf_disease_model_efficientnetb0.h5'")

# Evaluate model
loss, acc = model.evaluate(test_data)
print(f"\n✅ Final Test Accuracy: {acc:.4f}")

# Predictions
y_pred_probs = model.predict(test_data)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_data.classes
class_labels = list(test_data.class_indices.keys())

# Classification report
report = classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)
print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_labels, yticklabels=class_labels, cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Accuracy & loss curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# --- Metrics Calculation ---
try:
    aucs = roc_auc_score(test_data.labels, y_pred_probs, multi_class='ovr', average=None)
    auc_macro = roc_auc_score(test_data.labels, y_pred_probs, multi_class='ovr', average='macro')
    auc_weighted = roc_auc_score(test_data.labels, y_pred_probs, multi_class='ovr', average='weighted')
except Exception as e:
    aucs = auc_macro = auc_weighted = "N/A (not enough samples per class)"

precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)
f2 = fbeta_score(y_true, y_pred, beta=2, average='macro', zero_division=0)
fbeta = fbeta_score(y_true, y_pred, beta=0.5, average='macro', zero_division=0)

TP = np.diag(cm)
FP = cm.sum(axis=0) - TP
FN = cm.sum(axis=1) - TP
TN = cm.sum() - (FP + FN + TP)

sensitivity = TP / (TP + FN + 1e-8)
specificity = TN / (TN + FP + 1e-8)
miss_rate = FN / (FN + TP + 1e-8)
ppv = TP / (TP + FP + 1e-8)
npv = TN / (TN + FN + 1e-8)
fpr = FP / (FP + TN + 1e-8)
fnr = FN / (FN + TP + 1e-8)
lpr = sensitivity / (1 - specificity + 1e-8)
lnr = (1 - sensitivity) / (specificity + 1e-8)
fm_index = np.sqrt(precision * recall)

print("\n--- Model & Dataset Parameters ---")
print(f"1. Sample Size: {len(train_paths) + len(test_paths)}")
print(f"2. Train Dataset: {len(train_paths)} | Test Dataset: {len(test_paths)}")
print(f"3. Proposed Model: EfficientNetB0-based CNN")
print(f"4. Sample Size: {len(train_paths) + len(test_paths)}")
print(f"5. Input Size: {img_size}x{img_size}x3")
print(f"6. Hidden Layer Size: 256")
print(f"7. Number of Neurons in Hidden Layer: 256")
print(f"8. Activation Function of Hidden Layer: relu")
print(f"9. No of Neurons in Output Layer: {train_data.num_classes}")
print(f"10. Activation Function of Output Layer: softmax")
print(f"11. Optimizer: Adam")
print(f"12. Loss Function: categorical_crossentropy")
print(f"13. Performance Metrics: accuracy, precision, recall, F1, AUC")
print(f"14. No of Epochs: {epochs}")
print(f"15. Learning Rate: {learning_rate}")
print(f"16. Execution time (in ms): {execution_time_ms:.2f}")
print(f"17. AUCs (per class): {aucs}")
print(f"    Macro AUC: {auc_macro}")
print(f"    Weighted AUC: {auc_weighted}")
print(f"18. Training Accuracy: {history.history['accuracy'][-1]:.4f}")
print(f"19. Testing Accuracy: {acc:.4f}")
print(f"20. Validation Accuracy: {history.history['val_accuracy'][-1]:.4f}")
print(f"21. Loss: {loss:.4f}")
print(f"22. Validation Loss: {history.history['val_loss'][-1]:.4f}")
print(f"23. Precision (macro): {precision:.4f}")
print(f"24. Recall (macro): {recall:.4f}")
print(f"25. Classification Miss Rate (macro): {miss_rate.mean():.4f}")
print(f"26. Sensitivity (macro): {sensitivity.mean():.4f}")
print(f"27. Specificity (macro): {specificity.mean():.4f}")
print(f"28. F1-Score (macro): {f1:.4f}")
print(f"29. F2-Score (macro): {f2:.4f}")
print(f"30. FBeta-Score (beta=0.5, macro): {fbeta:.4f}")
print(f"31. Positive Predicted Value (macro): {ppv.mean():.4f}")
print(f"32. Negative Predicted Value (macro): {npv.mean():.4f}")
print(f"33. False Positive Ratio (macro): {fpr.mean():.4f}")
print(f"34. False Negative Ratio (macro): {fnr.mean():.4f}")
print(f"35. Likelihood Positive Ratio (macro): {lpr.mean():.4f}")
print(f"36. Likelihood Negative Ratio (macro): {lnr.mean():.4f}")
print(f"37. Fowlkes-Mallows index (macro): {fm_index:.4f}")
# Out:
# Found 1312 images belonging to 5 classes.
# Found 329 images belonging to 5 classes.
# ...
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 4, 4, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_8      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...
